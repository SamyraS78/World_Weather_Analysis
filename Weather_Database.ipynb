# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit
from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-5.1863671362564645, -21.231935232538802), (-21.49312336178798, 76.1291735762872), (89.3783203289764, 34.56756319636082), (-18.756493107308117, 10.118050124094935), (-8.469259505479414, 91.48210443514205), (-21.190932496407896, 12.84352195921366), (50.745376744633006, 3.785803622495081), (-83.63003971510437, -110.62498710535979), (16.160938733019933, -93.96929151516734), (28.660282927769344, -3.348081422962366), (52.05238739109305, 31.794691622167022), (-20.73355462398375, -133.7525756103256), (69.7800377973314, -125.12374099657231), (-56.588431082562344, 42.29165629049882), (-40.75668178793824, 72.56245790467673), (-49.25040305020475, 143.34034432031967), (7.887791706895072, 171.2133536995969), (-42.62816883841646, -166.99552922823648), (70.51513981381046, -37.528838803175915), (53.06804691341057, 171.26200370929593), (-56.22550764117911, -154.11114833935216), (-80.28324360524451, -125.31583271993843), (82.10527938242555, 0.4762538087107657), (51.3212533267353, 87.63723184808083), (-19.777433028337867, -137.9172555213205), (-67.22989227828123, 169.65263154051917), (-78.31997655339931, -62.106522656172416), (-40.12566926121798, 102.90850054687672), (33.27065945908309, -118.9395284222254), (-3.8475644596873337, 78.54853705738697), (-83.60830715622139, -36.25370338648827), (-69.51642646346636, -13.338025169361032), (-60.89938449104322, -1.3548712651852384), (1.8889663924379363, 83.15229647871325), (-70.57329267390145, -130.77453553272878), (52.544601058394676, -130.71787208444275), (54.82925834019838, 175.88002973348887), (52.80140986224316, -69.08502466557057), (38.79209280601333, -92.0587216492425), (31.49117528823821, -100.12608182554553), (44.086019167600085, 49.563685706111755), (-85.29264770378317, 179.8176852472871), (59.37506335515471, -80.64191401956923), (25.29392152960304, -61.36202328079425), (-33.80823631520299, 4.994486663183608), (73.42812622929739, 157.62964704267313), (-37.20792689253667, -28.642172563302267), (-79.3792847685934, 137.1660042103162), (78.95611639434978, -163.95519958147779), (-14.350240883981726, 159.3929826778339), (66.41923225839253, -96.03740106672677), (13.064439470806235, -175.18135934589753), (85.77850713182679, 177.3405720991986), (-78.44537266342668, 54.16847600990985), (56.37134624754995, -65.46509471679167), (89.914338972318, 18.230520108305058), (-78.219709345469, 139.7946984608722), (-58.12265289592346, -3.113803991634427), (-3.9913395788511252, -84.98147600230635), (-21.855590412262146, -6.575131102160725), (59.07803431754746, -174.31811680233977), (42.238408083216314, -31.76078188211261), (-39.286982804664504, 149.99100691364708), (16.394539713502283, -100.61330404991067), (-67.89948354331025, 120.23072494218599), (-0.498638974060853, 128.8667227512891), (-1.7161399505907724, 152.15789043219456), (42.56979488317381, -90.27253660888312), (-87.27447681224965, -27.97845324128059), (39.37376507803728, 13.620511816940734), (-46.569011945542, -72.15260148776461), (26.64595623519874, 20.739069495716876), (-42.655214394252994, 110.80201720150438), (33.45319461211132, -39.103582879732215), (13.972514568135466, -18.268608817647674), (-66.17928944790678, 54.66461432962984), (-79.3478600864384, -70.310594628183), (-41.55667668770537, -26.039239588845163), (39.08159526508061, 163.76672877588203), (12.794952192657405, 24.84494943162605), (-21.361119877098062, -155.6423619658146), (-67.6292803707483, -99.84364436712359), (-49.772824648388, -81.01793056764836), (-18.9044380158239, -49.208597324082035), (79.64606894393421, 78.35294339506419), (-55.87190154041168, 32.55697689903613), (-3.219263037016617, 25.93262398302454), (72.71051549608453, 38.69998905517326), (60.554373571195015, 34.797921443953925), (-75.66247394141249, 174.469636342968), (-53.64597324445665, -95.61910817902853), (24.270837366575705, 130.21030225362387), (-25.854148718242158, 68.74759250820892), (-40.95041770152695, -140.66553924555535), (55.95487846129029, 118.92332450927466), (57.40358705799079, 172.893863712714), (31.439156 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
#Get the nearest city using citypy module
from citipy import citipy

# %%
 # Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=36226143064b0119203b87da8d114a48

# %%
#Retrieve the following information fromt he API call:
#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
      # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 1 | berlevag
# Processing Record 4 of Set 1 | opuwo
# Processing Record 5 of Set 1 | padang
# Processing Record 6 of Set 1 | henties bay
# Processing Record 7 of Set 1 | flobecq
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | arriaga
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | horodnya
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | ulagan
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | rancho palos verdes
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | hambantota
# Processing Record 31 of Set 1 | prince rupert
# Processing Record 32 of Set 1 | beringovskiy
# Processing Record 33 of Set 1 | port-cartier
# Processing Record 34 of Set 1 | fulton
# Processing Record 35 of Set 1 | san angelo
# Processing Record 36 of Set 1 | fort-shevchenko
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 1 | the valley
# Processing Record 40 of Set 1 | luderitz
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | kirakira
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | sept-iles
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | talara
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | lakes entrance
# Processing Record 6 of Set 2 | zacualpan
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | platteville
# Processing Record 11 of Set 2 | capaci
# Processing Record 12 of Set 2 | coihaique
# Processing Record 13 of Set 2 | jalu
# Processing Record 14 of Set 2 | dakar
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | kutum
# Processing Record 18 of Set 2 | ituiutaba
# Processing Record 19 of Set 2 | dikson
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | kindu
# Processing Record 22 of Set 2 | ostrovnoy
# Processing Record 23 of Set 2 | podporozhye
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | nishihara
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | chara
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | codrington
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | horki
# Processing Record 32 of Set 2 | ardmore
# Processing Record 33 of Set 2 | pocone
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | lavrentiya
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | san cristobal
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | aberdeen
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | abu kamal
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | yantzaza
# Processing Record 47 of Set 2 | juegang
# Processing Record 48 of Set 2 | airai
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | mbanza-ngungu
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | viedma
# Processing Record 3 of Set 3 | ballina
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | mugur-aksy
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | tuktoyaktuk
# Processing Record 8 of Set 3 | sur
# Processing Record 9 of Set 3 | baboua
# City not found. Skipping...
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | mayor pablo lagerenza
# Processing Record 12 of Set 3 | solnechnyy
# Processing Record 13 of Set 3 | barcelos
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | saint-augustin
# Processing Record 17 of Set 3 | kondoa
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | vao
# Processing Record 21 of Set 3 | ilhabela
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | keroka
# Processing Record 24 of Set 3 | dauriya
# Processing Record 25 of Set 3 | broken hill
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | vardo
# Processing Record 29 of Set 3 | broome
# Processing Record 30 of Set 3 | yomou
# Processing Record 31 of Set 3 | svetlyy
# Processing Record 32 of Set 3 | senanga
# Processing Record 33 of Set 3 | pontianak
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | thap khlo
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | chuy
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | saint-leu
# Processing Record 40 of Set 3 | tonj
# Processing Record 41 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 3 | sao joao da barra
# Processing Record 43 of Set 3 | pangnirtung
# Processing Record 44 of Set 3 | algete
# Processing Record 45 of Set 3 | hilo
# Processing Record 46 of Set 3 | florence
# Processing Record 47 of Set 3 | ampanihy
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | kieta
# Processing Record 50 of Set 3 | gainesville
# Processing Record 1 of Set 4 | shizilu
# Processing Record 2 of Set 4 | lomonosov
# Processing Record 3 of Set 4 | loikaw
# Processing Record 4 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 4 | havelock
# Processing Record 6 of Set 4 | rapar
# Processing Record 7 of Set 4 | jinchengjiang
# City not found. Skipping...
# Processing Record 8 of Set 4 | anadyr
# Processing Record 9 of Set 4 | sovetskiy
# Processing Record 10 of Set 4 | florianopolis
# Processing Record 11 of Set 4 | merrill
# Processing Record 12 of Set 4 | buraydah
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | saint anthony
# Processing Record 15 of Set 4 | dunedin
# Processing Record 16 of Set 4 | lebanon
# Processing Record 17 of Set 4 | olafsvik
# Processing Record 18 of Set 4 | hualmay
# Processing Record 19 of Set 4 | morada nova
# Processing Record 20 of Set 4 | praia
# Processing Record 21 of Set 4 | vilyuysk
# Processing Record 22 of Set 4 | waingapu
# Processing Record 23 of Set 4 | paamiut
# Processing Record 24 of Set 4 | carnarvon
# Processing Record 25 of Set 4 | cranbrook
# Processing Record 26 of Set 4 | lata
# Processing Record 27 of Set 4 | honningsvag
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | kaeo
# Processing Record 30 of Set 4 | amapa
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 4 | hofn
# Processing Record 36 of Set 4 | filadelfia
# Processing Record 37 of Set 4 | laguna
# Processing Record 38 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 4 | mendi
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | chapais
# Processing Record 42 of Set 4 | necochea
# Processing Record 43 of Set 4 | okhotsk
# Processing Record 44 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 4 | golyshmanovo
# Processing Record 46 of Set 4 | kilgore
# Processing Record 47 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 4 | pangai
# Processing Record 49 of Set 4 | maceio
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | kimbe
# Processing Record 2 of Set 5 | pimentel
# Processing Record 3 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 5 | uk
# City not found. Skipping...
# Processing Record 5 of Set 5 | rorvik
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | sawtell
# Processing Record 9 of Set 5 | havoysund
# Processing Record 10 of Set 5 | nyurba
# Processing Record 11 of Set 5 | aykhal
# Processing Record 12 of Set 5 | nueva helvecia
# Processing Record 13 of Set 5 | nova ushytsya
# Processing Record 14 of Set 5 | guerrero negro
# Processing Record 15 of Set 5 | rio gallegos
# Processing Record 16 of Set 5 | nokaneng
# Processing Record 17 of Set 5 | nome
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | boo
# Processing Record 21 of Set 5 | bayt yafa
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 5 | bereda
# Processing Record 24 of Set 5 | kahului
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | marathon
# Processing Record 27 of Set 5 | mutoko
# Processing Record 28 of Set 5 | veraval
# Processing Record 29 of Set 5 | ginda
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 5 | tilichiki
# Processing Record 33 of Set 5 | chumikan
# Processing Record 34 of Set 5 | monteagudo
# Processing Record 35 of Set 5 | omsukchan
# Processing Record 36 of Set 5 | buala
# Processing Record 37 of Set 5 | santa fe
# Processing Record 38 of Set 5 | fairbanks
# Processing Record 39 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 5 | inhambane
# Processing Record 41 of Set 5 | kruisfontein
# Processing Record 42 of Set 5 | catuday
# Processing Record 43 of Set 5 | woodward
# Processing Record 44 of Set 5 | labuhan
# Processing Record 45 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | jamame
# Processing Record 48 of Set 5 | kunyang
# Processing Record 49 of Set 5 | deputatskiy
# Processing Record 50 of Set 5 | lujan
# Processing Record 1 of Set 6 | lasa
# Processing Record 2 of Set 6 | siuna
# Processing Record 3 of Set 6 | honiara
# Processing Record 4 of Set 6 | kodiak
# Processing Record 5 of Set 6 | terenos
# Processing Record 6 of Set 6 | whitehorse
# Processing Record 7 of Set 6 | mpika
# Processing Record 8 of Set 6 | dunn
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | kosh-agach
# Processing Record 12 of Set 6 | mabaruma
# Processing Record 13 of Set 6 | lapeer
# Processing Record 14 of Set 6 | concordia
# Processing Record 15 of Set 6 | linxia
# Processing Record 16 of Set 6 | lebu
# Processing Record 17 of Set 6 | dire
# Processing Record 18 of Set 6 | bubaque
# Processing Record 19 of Set 6 | high rock
# Processing Record 20 of Set 6 | agadez
# Processing Record 21 of Set 6 | bitung
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | morant bay
# Processing Record 24 of Set 6 | tuatapere
# Processing Record 25 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 26 of Set 6 | chokurdakh
# Processing Record 27 of Set 6 | shubarshi
# Processing Record 28 of Set 6 | port blair
# Processing Record 29 of Set 6 | khorixas
# Processing Record 30 of Set 6 | kavaratti
# Processing Record 31 of Set 6 | sanok
# Processing Record 32 of Set 6 | beaverlodge
# Processing Record 33 of Set 6 | tual
# Processing Record 34 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 6 | megion
# Processing Record 36 of Set 6 | novoseleznevo
# Processing Record 37 of Set 6 | sampit
# Processing Record 38 of Set 6 | ikryanoye
# Processing Record 39 of Set 6 | mahenge
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | berdigestyakh
# Processing Record 42 of Set 6 | mokolo
# Processing Record 43 of Set 6 | mogadishu
# Processing Record 44 of Set 6 | ha tinh
# Processing Record 45 of Set 6 | port hardy
# Processing Record 46 of Set 6 | northam
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | thinadhoo
# Processing Record 49 of Set 6 | caohe
# Processing Record 50 of Set 6 | waipawa
# Processing Record 1 of Set 7 | gandajika
# Processing Record 2 of Set 7 | lodingen
# Processing Record 3 of Set 7 | nantucket
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | tiksi
# Processing Record 6 of Set 7 | kopavogur
# Processing Record 7 of Set 7 | atar
# Processing Record 8 of Set 7 | teya
# Processing Record 9 of Set 7 | chicama
# Processing Record 10 of Set 7 | srednekolymsk
# Processing Record 11 of Set 7 | goroka
# Processing Record 12 of Set 7 | praya
# Processing Record 13 of Set 7 | shiraz
# Processing Record 14 of Set 7 | andenes
# Processing Record 15 of Set 7 | bundaberg
# Processing Record 16 of Set 7 | touros
# Processing Record 17 of Set 7 | puerto escondido
# Processing Record 18 of Set 7 | meulaboh
# Processing Record 19 of Set 7 | wahiawa
# Processing Record 20 of Set 7 | sijunjung
# Processing Record 21 of Set 7 | bamiantong
# Processing Record 22 of Set 7 | pevek
# Processing Record 23 of Set 7 | kommunisticheskiy
# Processing Record 24 of Set 7 | marsh harbour
# Processing Record 25 of Set 7 | port victoria
# Processing Record 26 of Set 7 | takapau
# Processing Record 27 of Set 7 | tartagal
# Processing Record 28 of Set 7 | novikovo
# Processing Record 29 of Set 7 | hertford
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | jardim
# Processing Record 32 of Set 7 | flinders
# Processing Record 33 of Set 7 | sao filipe
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | kodinsk
# Processing Record 36 of Set 7 | belmonte
# Processing Record 37 of Set 7 | bima
# Processing Record 38 of Set 7 | turukhansk
# Processing Record 39 of Set 7 | pithora
# Processing Record 40 of Set 7 | ponta do sol
# Processing Record 41 of Set 7 | goderich
# Processing Record 42 of Set 7 | saldanha
# Processing Record 43 of Set 7 | katsuura
# Processing Record 44 of Set 7 | sitka
# Processing Record 45 of Set 7 | klaksvik
# Processing Record 46 of Set 7 | vila
# Processing Record 47 of Set 7 | galesong
# Processing Record 48 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 7 | turayf
# Processing Record 50 of Set 7 | upernavik
# Processing Record 1 of Set 8 | khandyga
# Processing Record 2 of Set 8 | paris
# Processing Record 3 of Set 8 | bairnsdale
# Processing Record 4 of Set 8 | cumpas
# Processing Record 5 of Set 8 | tubuala
# Processing Record 6 of Set 8 | kaputa
# Processing Record 7 of Set 8 | asau
# Processing Record 8 of Set 8 | naze
# Processing Record 9 of Set 8 | hasaki
# Processing Record 10 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 11 of Set 8 | moose factory
# Processing Record 12 of Set 8 | umm kaddadah
# Processing Record 13 of Set 8 | costinesti
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | havre
# Processing Record 16 of Set 8 | itatinga
# Processing Record 17 of Set 8 | oussouye
# Processing Record 18 of Set 8 | samarkand
# Processing Record 19 of Set 8 | santiago
# Processing Record 20 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | ahipara
# Processing Record 23 of Set 8 | emerald
# Processing Record 24 of Set 8 | portland
# Processing Record 25 of Set 8 | arnstadt
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | keflavik
# Processing Record 29 of Set 8 | te anau
# Processing Record 30 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 8 | qinzhou
# Processing Record 32 of Set 8 | yarmouth
# Processing Record 33 of Set 8 | leh
# Processing Record 34 of Set 8 | ossora
# Processing Record 35 of Set 8 | beatrice
# Processing Record 36 of Set 8 | cayenne
# Processing Record 37 of Set 8 | rawson
# Processing Record 38 of Set 8 | ola
# Processing Record 39 of Set 8 | iskateley
# Processing Record 40 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 41 of Set 8 | verkhnyaya inta
# Processing Record 42 of Set 8 | senno
# Processing Record 43 of Set 8 | half moon bay
# Processing Record 44 of Set 8 | witu
# Processing Record 45 of Set 8 | boyolangu
# Processing Record 46 of Set 8 | gazanjyk
# Processing Record 47 of Set 8 | fukue
# Processing Record 48 of Set 8 | comodoro rivadavia
# Processing Record 49 of Set 8 | bonavista
# Processing Record 50 of Set 8 | siyabuswa
# Processing Record 1 of Set 9 | mandalgovi
# Processing Record 2 of Set 9 | bandar-e lengeh
# Processing Record 3 of Set 9 | innisfail
# Processing Record 4 of Set 9 | natal
# Processing Record 5 of Set 9 | luau
# Processing Record 6 of Set 9 | faya
# Processing Record 7 of Set 9 | brigantine
# Processing Record 8 of Set 9 | nouadhibou
# Processing Record 9 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 11 of Set 9 | muisne
# Processing Record 12 of Set 9 | kloulklubed
# Processing Record 13 of Set 9 | alizai
# Processing Record 14 of Set 9 | yerbogachen
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | capitao poco
# Processing Record 17 of Set 9 | cam ranh
# Processing Record 18 of Set 9 | ambon
# Processing Record 19 of Set 9 | athabasca
# Processing Record 20 of Set 9 | trinidad
# Processing Record 21 of Set 9 | nidamangalam
# Processing Record 22 of Set 9 | skjervoy
# Processing Record 23 of Set 9 | evensk
# Processing Record 24 of Set 9 | arlit
# Processing Record 25 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 9 | lugus
# Processing Record 28 of Set 9 | harper
# Processing Record 29 of Set 9 | bahia blanca
# Processing Record 30 of Set 9 | dharchula
# Processing Record 31 of Set 9 | ayacucho
# Processing Record 32 of Set 9 | svetlaya
# Processing Record 33 of Set 9 | daru
# Processing Record 34 of Set 9 | kyzyl-suu
# Processing Record 35 of Set 9 | yamada
# Processing Record 36 of Set 9 | roma
# Processing Record 37 of Set 9 | fort nelson
# Processing Record 38 of Set 9 | orbetello
# Processing Record 39 of Set 9 | halden
# Processing Record 40 of Set 9 | nsawam
# Processing Record 41 of Set 9 | minsk
# Processing Record 42 of Set 9 | pyshchug
# Processing Record 43 of Set 9 | plettenberg bay
# Processing Record 44 of Set 9 | natchitoches
# Processing Record 45 of Set 9 | khudaganj
# Processing Record 46 of Set 9 | gerash
# Processing Record 47 of Set 9 | egvekinot
# Processing Record 48 of Set 9 | fukuma
# Processing Record 49 of Set 9 | kuytun
# Processing Record 50 of Set 9 | san luis
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | sibolga
# Processing Record 3 of Set 10 | phan thiet
# Processing Record 4 of Set 10 | vaitape
# Processing Record 5 of Set 10 | karratha
# Processing Record 6 of Set 10 | general roca
# Processing Record 7 of Set 10 | gabu
# Processing Record 8 of Set 10 | aras
# Processing Record 9 of Set 10 | sompeta
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | collie
# Processing Record 12 of Set 10 | tobias barreto
# Processing Record 13 of Set 10 | linjiang
# Processing Record 14 of Set 10 | casas grandes
# Processing Record 15 of Set 10 | klyuchi
# Processing Record 16 of Set 10 | umm lajj
# Processing Record 17 of Set 10 | puri
# Processing Record 18 of Set 10 | alta floresta
# Processing Record 19 of Set 10 | mana
# Processing Record 20 of Set 10 | maracacume
# Processing Record 21 of Set 10 | verkhoyansk
# Processing Record 22 of Set 10 | muncar
# Processing Record 23 of Set 10 | conde
# Processing Record 24 of Set 10 | melita
# Processing Record 25 of Set 10 | korla
# Processing Record 26 of Set 10 | canandaigua
# Processing Record 27 of Set 10 | campbell river
# Processing Record 28 of Set 10 | penzance
# Processing Record 29 of Set 10 | boissevain
# Processing Record 30 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 10 | imeni vorovskogo
# Processing Record 32 of Set 10 | itoman
# Processing Record 33 of Set 10 | sao gabriel da cachoeira
# Processing Record 34 of Set 10 | vila franca do campo
# Processing Record 35 of Set 10 | esil
# Processing Record 36 of Set 10 | isangel
# Processing Record 37 of Set 10 | manuk mangkaw
# Processing Record 38 of Set 10 | victoria point
# Processing Record 39 of Set 10 | bilibino
# Processing Record 40 of Set 10 | trail
# Processing Record 41 of Set 10 | suntar
# Processing Record 42 of Set 10 | port-gentil
# Processing Record 43 of Set 10 | sisimiut
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | palmer
# Processing Record 46 of Set 10 | pochutla
# Processing Record 47 of Set 10 | pushkino
# Processing Record 48 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 10 | udachnyy
# Processing Record 50 of Set 10 | dhidhdhoo
# Processing Record 1 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 11 | lima
# Processing Record 3 of Set 11 | ancud
# Processing Record 4 of Set 11 | cabedelo
# Processing Record 5 of Set 11 | golden
# Processing Record 6 of Set 11 | gigmoto
# Processing Record 7 of Set 11 | elliot
# Processing Record 8 of Set 11 | college
# Processing Record 9 of Set 11 | moerai
# Processing Record 10 of Set 11 | irbeyskoye
# Processing Record 11 of Set 11 | twin falls
# Processing Record 12 of Set 11 | verkhnevilyuysk
# Processing Record 13 of Set 11 | palmerston
# Processing Record 14 of Set 11 | quatre cocos
# Processing Record 15 of Set 11 | itabira
# Processing Record 16 of Set 11 | barrancas
# Processing Record 17 of Set 11 | korem
# Processing Record 18 of Set 11 | yuksekova
# Processing Record 19 of Set 11 | beyneu
# Processing Record 20 of Set 11 | strezhevoy
# Processing Record 21 of Set 11 | santiago del estero
# Processing Record 22 of Set 11 | ilulissat
# Processing Record 23 of Set 11 | muriwai beach
# Processing Record 24 of Set 11 | enshi
# Processing Record 25 of Set 11 | byron bay
# Processing Record 26 of Set 11 | mitchell
# Processing Record 27 of Set 11 | santa marta
# Processing Record 28 of Set 11 | rabaul
# Processing Record 29 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 11 | la rochelle
# Processing Record 31 of Set 11 | la ronge
# Processing Record 32 of Set 11 | conakry
# Processing Record 33 of Set 11 | santa maria da vitoria
# Processing Record 34 of Set 11 | san carlos de bariloche
# Processing Record 35 of Set 11 | conceicao da barra
# Processing Record 36 of Set 11 | mnogovershinnyy
# Processing Record 37 of Set 11 | point fortin
# Processing Record 38 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | dingle
# Processing Record 40 of Set 11 | torres
# Processing Record 41 of Set 11 | merauke
# Processing Record 42 of Set 11 | mugumu
# Processing Record 43 of Set 11 | camocim
# Processing Record 44 of Set 11 | richards bay
# Processing Record 45 of Set 11 | sedkyrkeshch
# Processing Record 46 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 11 | krasnovishersk
# Processing Record 48 of Set 11 | pacific grove
# Processing Record 49 of Set 11 | ler
# Processing Record 50 of Set 11 | big rapids
# Processing Record 1 of Set 12 | ghanzi
# Processing Record 2 of Set 12 | araceli
# Processing Record 3 of Set 12 | parabel
# Processing Record 4 of Set 12 | cartagena
# Processing Record 5 of Set 12 | atocha
# Processing Record 6 of Set 12 | tamandare
# Processing Record 7 of Set 12 | frontera
# Processing Record 8 of Set 12 | chama
# Processing Record 9 of Set 12 | mayskiy
# Processing Record 10 of Set 12 | ventimiglia
# Processing Record 11 of Set 12 | sopotu nou
# Processing Record 12 of Set 12 | namatanai
# Processing Record 13 of Set 12 | tessalit
# Processing Record 14 of Set 12 | tautira
# Processing Record 15 of Set 12 | gallup
# Processing Record 16 of Set 12 | taos
# Processing Record 17 of Set 12 | starozhilovo
# Processing Record 18 of Set 12 | santa maria
# Processing Record 19 of Set 12 | alpena
# Processing Record 20 of Set 12 | nan
# Processing Record 21 of Set 12 | sambava
# Processing Record 22 of Set 12 | teahupoo
# Processing Record 23 of Set 12 | agua dulce
# Processing Record 24 of Set 12 | aklavik
# Processing Record 25 of Set 12 | salym
# Processing Record 26 of Set 12 | motala
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | simplicio mendes
# Processing Record 29 of Set 12 | eureka
# Processing Record 30 of Set 12 | australind
# Processing Record 31 of Set 12 | cap-haitien
# Processing Record 32 of Set 12 | koutsouras
# Processing Record 33 of Set 12 | charlottesville
# Processing Record 34 of Set 12 | shahdol
# Processing Record 35 of Set 12 | muros
# Processing Record 36 of Set 12 | nevers
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | samsun
# Processing Record 39 of Set 12 | furstenfeldbruck
# City not found. Skipping...
# Processing Record 40 of Set 12 | lodja
# Processing Record 41 of Set 12 | hamilton
# Processing Record 42 of Set 12 | poum
# Processing Record 43 of Set 12 | kurilsk
# Processing Record 44 of Set 12 | ihosy
# Processing Record 45 of Set 12 | senneterre
# Processing Record 46 of Set 12 | putina
# Processing Record 47 of Set 12 | teguldet
# Processing Record 48 of Set 12 | peniche
# Processing Record 49 of Set 12 | tura
# Processing Record 50 of Set 12 | pathein
# Processing Record 1 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 13 | maple creek
# Processing Record 3 of Set 13 | kara
# Processing Record 4 of Set 13 | camacha
# Processing Record 5 of Set 13 | mahanje
# Processing Record 6 of Set 13 | ivanishchi
# Processing Record 7 of Set 13 | kununurra
# Processing Record 8 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 13 | santana do livramento
# Processing Record 10 of Set 13 | rocha
# Processing Record 11 of Set 13 | rockhampton
# Processing Record 12 of Set 13 | ust-kuyga
# Processing Record 13 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 13 | mount isa
# Processing Record 15 of Set 13 | bara
# Processing Record 16 of Set 13 | ichnya
# Processing Record 17 of Set 13 | bilma
# Processing Record 18 of Set 13 | baykit
# Processing Record 19 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 13 | tomatlan
# Processing Record 22 of Set 13 | jacareacanga
# Processing Record 23 of Set 13 | fethiye
# Processing Record 24 of Set 13 | saint-georges
# Processing Record 25 of Set 13 | lilongwe
# Processing Record 26 of Set 13 | ugoofaaru
# Processing Record 27 of Set 13 | halifax
# Processing Record 28 of Set 13 | aguas vermelhas
# Processing Record 29 of Set 13 | tsogni
# Processing Record 30 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 32 of Set 13 | nhulunbuy
# Processing Record 33 of Set 13 | kathu
# Processing Record 34 of Set 13 | katangli
# Processing Record 35 of Set 13 | saint-joseph
# Processing Record 36 of Set 13 | storforshei
# Processing Record 37 of Set 13 | minbu
# Processing Record 38 of Set 13 | shelby
# Processing Record 39 of Set 13 | matara
# Processing Record 40 of Set 13 | zhanaozen
# Processing Record 41 of Set 13 | hauterive
# Processing Record 42 of Set 13 | santa cruz
# Processing Record 43 of Set 13 | itarema
# Processing Record 44 of Set 13 | dindori
# Processing Record 45 of Set 13 | darhan
# Processing Record 46 of Set 13 | ust-nera
# Processing Record 47 of Set 13 | ternate
# Processing Record 48 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 13 | perth
# Processing Record 50 of Set 13 | ambilobe
# Processing Record 1 of Set 14 | chulman
# Processing Record 2 of Set 14 | tosya
# Processing Record 3 of Set 14 | goma
# Processing Record 4 of Set 14 | waksma
# City not found. Skipping...
# Processing Record 5 of Set 14 | saquena
# Processing Record 6 of Set 14 | mastic beach
# Processing Record 7 of Set 14 | amuntai
# Processing Record 8 of Set 14 | delijan
# Processing Record 9 of Set 14 | casa nova
# Processing Record 10 of Set 14 | nanakuli
# Processing Record 11 of Set 14 | demirci
# Processing Record 12 of Set 14 | skanevik
# City not found. Skipping...
# Processing Record 13 of Set 14 | biak
# Processing Record 14 of Set 14 | mangaratiba
# Processing Record 15 of Set 14 | anchorage
# Processing Record 16 of Set 14 | granville
# Processing Record 17 of Set 14 | constantine
# Processing Record 18 of Set 14 | chengmai
# City not found. Skipping...
# Processing Record 19 of Set 14 | anito
# Processing Record 20 of Set 14 | rabo de peixe
# Processing Record 21 of Set 14 | fortuna
# Processing Record 22 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 23 of Set 14 | marshalltown
# Processing Record 24 of Set 14 | san martin
# Processing Record 25 of Set 14 | zyryanka
# Processing Record 26 of Set 14 | promysla
# City not found. Skipping...
# Processing Record 27 of Set 14 | conceicao do araguaia
# Processing Record 28 of Set 14 | kokkola
# Processing Record 29 of Set 14 | lobito
# Processing Record 30 of Set 14 | pucara
# Processing Record 31 of Set 14 | pattani
# Processing Record 32 of Set 14 | hokitika
# Processing Record 33 of Set 14 | santa rosa
# Processing Record 34 of Set 14 | tias
# Processing Record 35 of Set 14 | mosquera
# Processing Record 36 of Set 14 | asyut
# Processing Record 37 of Set 14 | gushikawa
# Processing Record 38 of Set 14 | bridlington
# Processing Record 39 of Set 14 | sungaipenuh
# Processing Record 40 of Set 14 | palana
# Processing Record 41 of Set 14 | nelspruit
# Processing Record 42 of Set 14 | tefe
# Processing Record 43 of Set 14 | huangnihe
# Processing Record 44 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 14 | ibra
# Processing Record 46 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 14 | ahuimanu
# Processing Record 48 of Set 14 | monrovia
# Processing Record 49 of Set 14 | shache
# Processing Record 50 of Set 14 | vidim
# Processing Record 1 of Set 15 | oranjemund
# Processing Record 2 of Set 15 | magadan
# Processing Record 3 of Set 15 | venosa
# Processing Record 4 of Set 15 | baculin
# Processing Record 5 of Set 15 | tukrah
# Processing Record 6 of Set 15 | yatou
# Processing Record 7 of Set 15 | polson
# Processing Record 8 of Set 15 | kupang
# Processing Record 9 of Set 15 | samana
# Processing Record 10 of Set 15 | serowe
# Processing Record 11 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 15 | ketchikan
# Processing Record 13 of Set 15 | soavinandriana
# Processing Record 14 of Set 15 | cruz alta
# Processing Record 15 of Set 15 | beckley
# Processing Record 16 of Set 15 | savannah bight
# Processing Record 17 of Set 15 | bowen
# Processing Record 18 of Set 15 | grand gaube
# Processing Record 19 of Set 15 | aksha
# Processing Record 20 of Set 15 | burica
# City not found. Skipping...
# Processing Record 21 of Set 15 | kijang
# Processing Record 22 of Set 15 | monte patria
# Processing Record 23 of Set 15 | dwarka
# Processing Record 24 of Set 15 | timra
# Processing Record 25 of Set 15 | zvishavane
# Processing Record 26 of Set 15 | stoina
# Processing Record 27 of Set 15 | ontario
# Processing Record 28 of Set 15 | tulu bolo
# Processing Record 29 of Set 15 | vavuniya
# Processing Record 30 of Set 15 | madingou
# Processing Record 31 of Set 15 | yumen
# Processing Record 32 of Set 15 | cheyenne
# Processing Record 33 of Set 15 | husavik
# Processing Record 34 of Set 15 | lenoir city
# Processing Record 35 of Set 15 | paso de los toros
# Processing Record 36 of Set 15 | elat
# Processing Record 37 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 15 | zelenoborskiy
# Processing Record 39 of Set 15 | los llanos de aridane
# Processing Record 40 of Set 15 | seydi
# Processing Record 41 of Set 15 | olinda
# Processing Record 42 of Set 15 | mayumba
# Processing Record 43 of Set 15 | farafangana
# Processing Record 44 of Set 15 | kalininsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 #Add the data to a new dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Georgetown      MY   5.4112  100.3354     80.53        92          20
# 1      Berlevag      NO  70.8578   29.0864     46.40        81           0
# 2         Opuwo      NA -18.0607   13.8400     61.75        34         100
# 3        Padang      ID  -0.9492  100.3543     78.13        82         100
# 4   Henties Bay      NA -22.1160   14.2845     67.69        50         100
# 5       Flobecq      BE  50.7526    3.7315     61.84        91         100
# 6  Punta Arenas      CL -53.1500  -70.9167     48.31        49           0
# 7       Arriaga      MX  16.2333  -93.9000     87.96        62         100
# 8         Adrar      MR  20.5022  -10.0711     97.61        11         100
# 9      Horodnya      UA  51.8909   31.5974     55.06        84           6
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1        4.61           clear sky
# 2        8.57     overcast clouds
# 3        2.80     overcast clouds
# 4        9.75     overcast clouds
# 5       12.59     overcast clouds
# 6       12.66           clear sky
# 7        8.88     overcast clouds
# 8       11.23     overcast clouds
# 9        6.67           clear sky

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10000\1966149458.py in <module>
#       4
#       5 # Export the City_Data into a CSV.
# ----> 6 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# c:\Users\Samyr\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# c:\Users\Samyr\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# c:\Users\Samyr\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# c:\Users\Samyr\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
